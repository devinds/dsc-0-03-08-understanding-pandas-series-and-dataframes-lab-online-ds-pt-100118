# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
df.columns = [x.lower() for x in df.columns]
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df.set_index("linename").head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df.reset_index().head()
# Out:
#    index   c/a  unit       scp station linename division        date  \
# 0      0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018
# 1      1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018
# 2      2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018
# 3      3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018
# 4      4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018
#
#        time     desc  entries  \
# 0  00:00:00  REGULAR  6736067
# 1  04:00:00  REGULAR  6736087
# 2  08:00:00  REGULAR  6736105
# 3  12:00:00  REGULAR  6736180
# 4  16:00:00  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
#df["Num_Lines"] = df.groupby("station")["linename"].transform('count')

df['num_lines'] = df.linename.map(lambda x: len(x))

# %%
df.sort_values('num_lines', ascending = False).head()
# Out:
#          c/a  unit       scp         station      linename division  \
# 132292  R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2686    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2673    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2674    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2675    A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
#
#               date      time     desc  entries  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
#
#         exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# ...

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.lower()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df.date=pd.to_datetime(df.date)
df['weekday']=df.date.dt.dayofweek
df.head()
#df['weekday'] = pd.to_datetime(df.weekday, format='%A')
#make sure date column is in datatime format
#create a column called weekday that takes in the info from date, finds the weekday, and store that day of the week
#in the same row as weekday. 
#subtract exits from entries to get traffic. 
#group entries by date.
# Out:
#     c/a  unit       scp station linename division       date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    num_lines  weekday
# 0          7        5
# ...

# %%
traffic = df.groupby('weekday').sum()
traffic.plot(kind='barh', legend=False)

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here

# %% [markdown]
# # Drop a couple of columns

# %%
df = df.drop(['c/a', 'scp'], axis=1)
df.head()
# Out:
#    unit station linename division       date      time     desc  entries  \
# 0  R051   59 ST  NQR456W      BMT 2018-08-25  00:00:00  REGULAR  6736067
# 1  R051   59 ST  NQR456W      BMT 2018-08-25  04:00:00  REGULAR  6736087
# 2  R051   59 ST  NQR456W      BMT 2018-08-25  08:00:00  REGULAR  6736105
# 3  R051   59 ST  NQR456W      BMT 2018-08-25  12:00:00  REGULAR  6736180
# 4  R051   59 ST  NQR456W      BMT 2018-08-25  16:00:00  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    num_lines  weekday
# 0          7        5
# 1          7        5
# 2          7        5
# 3          7        5
# 4          7        5
